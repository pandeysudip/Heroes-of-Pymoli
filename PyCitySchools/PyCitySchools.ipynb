# %%
#Importing some modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#Defining path and file to load
school_data_to_load=os.path.join("Resources","schools_complete.csv" )
student_data_to_load=os.path.join("Resources","students_complete.csv" )

# %%
# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# %%
# looking the data first
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# looking the data first
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Combine the data into a single dataset.  
school = (pd.merge(student_data, school_data, how="left", 
                                 on=["school_name", "school_name"]))

# %%
# looking the data first
school.tail()
# Out:
#        Student ID     student_name gender grade         school_name  \
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID     type  size   budget
# 39165             99          90         14  Charter  1635  1043130
# 39166             95          70         14  Charter  1635  1043130
# 39167             73          84         14  Charter  1635  1043130
# 39168             99          90         14  Charter  1635  1043130
# 39169             95          75         14  Charter  1635  1043130

# %%
#looking for shape
school.shape
print(f'The number of rows is:{school.shape[0]} and number of columns is: {school.shape[1]}')
# Out:
# The number of rows is:39170 and number of columns is: 11

# %%
#looking for dtypes and null value
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39170 entries, 0 to 39169
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
#  7   School ID      39170 non-null  int64
#  8   type           39170 non-null  object
#  9   size           39170 non-null  int64
#  10  budget         39170 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 3.6+ MB

# %%
#Describing the dataframe
school.describe()
# Out:
#          Student ID  reading_score    math_score     School ID          size  \
# count  39170.000000    39170.00000  39170.000000  39170.000000  39170.000000
# mean   19584.500000       81.87784     78.985371      6.978172   3332.957110
# std    11307.549359       10.23958     12.309968      4.444329   1323.914069
# min        0.000000       63.00000     55.000000      0.000000    427.000000
# 25%     9792.250000       73.00000     69.000000      3.000000   1858.000000
# 50%    19584.500000       82.00000     79.000000      7.000000   2949.000000
# 75%    29376.750000       91.00000     89.000000     11.000000   4635.000000
# max    39169.000000       99.00000     99.000000     14.000000   4976.000000
#
#              budget
# count  3.917000e+04
# mean   2.117241e+06
# std    8.749987e+05
# min    2.480870e+05
# 25%    1.081356e+06
# 50%    1.910635e+06
# 75%    3.022020e+06
# max    3.124928e+06

# %%
#columns name
school.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
school.value_counts('budget')
# Out:
# budget
# 3124928    4976
# 3094650    4761
# 3022020    4635
# 2547363    3999
# 1884411    2949
# 1910635    2917
# 1763916    2739
# 1319574    2283
# 1081356    1858
# 1049400    1800
# 1056600    1761
# 1043130    1635
# 917500     1468
# 585858      962
# 248087      427
# dtype: int64

# %%
#District Summary
tot_school=school.school_name.nunique()
tot_student=school['Student ID'].count()
tot_budget=(school.groupby('school_name')['budget'].sum()
        /school.groupby('school_name')['budget'].count()).sum()
avg_math=school.math_score.mean()
avg_read=school.reading_score.mean()
perc_math=(school.loc[school.math_score >=70, 'Student ID'].count()/tot_student)*100
perc_read=(school.loc[school.reading_score >=70, 'Student ID'].count()/tot_student)*100
perc_both=((school.loc[(school.reading_score >=70) & (school.math_score >=70) ,'Student ID']
            .count()/tot_student)*100)
district_summary=pd.DataFrame({'Total Schools':[tot_school],
             'Total Students':[tot_student],
             'Total Budget':[tot_budget],
             'Average Math Score':[avg_math],
             'Average Reading Score':[avg_read],
             '% Passing Math':[perc_math],
             '% Passing Reading':[perc_read],          
             '% Overall Passing':[perc_both]})
district_summary['Total Budget']=district_summary['Total Budget'].map('${:,.2f}'.format)
district_summary
# Out:
#    Total Schools  Total Students    Total Budget  Average Math Score  \
# 0             15           39170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
school.loc[school.math_score >=70, 'Student ID']
# Out:
# 0            0
# 4            4
# 5            5
# 6            6
# 8            8
#          ...
# 39165    39165
# 39166    39166
# 39167    39167
# 39168    39168
# 39169    39169
# Name: Student ID, Length: 29370, dtype: int64

# %%
math_pass=school.loc[school.math_score >=70, ['school_name','math_score']]
pas=math_pass.groupby('school_name')['math_score'].count()
total=group['math_score'].count()
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: math_score, dtype: int64

# %%
#School Summary
group=school.groupby('school_name')
total_students=group['Student ID'].count()
#school_type=group['type'].keys
total_budget=group['budget'].sum()/group['budget'].count()
per_stu_budget=total_budget/total_students
avg_math_score=group['math_score'].mean()
avg_read_score=group['reading_score'].mean()

math_pass=school.loc[school.math_score >=70, ['school_name','math_score']]
perc_math_score=(math_pass.groupby('school_name')['math_score'].count()/group['math_score'].count())*100

read_pass=school.loc[school.reading_score >=70, ['school_name','reading_score']]
perc_read_score=(read_pass.groupby('school_name')['reading_score'].count()/group['reading_score'].count())*100

overall_pass=school.loc[(school.reading_score >=70) & (school.math_score >=70) , ['school_name','reading_score']]
perc_overall_score=(overall_pass.groupby('school_name')['reading_score'].count()/group['reading_score'].count())*100

#perc_math_score=(group['math_score'].count().loc[lambda p: p>70]/total_students)*100

school_summary=pd.DataFrame(total_students)
school_summary['Total Budgets']=total_budget
school_summary['Per Student Budget']=per_stu_budget
school_summary['Average Math Score']=avg_math_score
school_summary['Average Reading Score']=avg_read_score
school_summary["% Passing Math"]=perc_math_score
school_summary["% Passing Reading"]=perc_read_score
school_summary["% Overall Passing"]=perc_overall_score

school_summary.rename(columns={'Student ID': "Total Students"}, inplace=True)
school_summary
# Out:
#                        Total Students  Total Budgets  Per Student Budget  \
# school_name
# Bailey High School               4976      3124928.0               628.0
# Cabrera High School              1858      1081356.0               582.0
# Figueroa High School             2949      1884411.0               639.0
# Ford High School                 2739      1763916.0               644.0
# Griffin High School              1468       917500.0               625.0
# Hernandez High School            4635      3022020.0               652.0
# Holden High School                427       248087.0               581.0
# Huang High School                2917      1910635.0               655.0
# Johnson High School              4761      3094650.0               650.0
# Pena High School                  962       585858.0               609.0
# Rodriguez High School            3999      2547363.0               637.0
# Shelton High School              1761      1056600.0               600.0
# ...

# %%
group['math_score'].count().loc[lambda p: p>70]
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: math_score, dtype: int64

# %%
#Bottom Performing Schools (By % Overall Passing)

# %%
#Math Scores by Grade**
ninth_grade=school.loc[school.grade=='9th', 'grade',]
tenth_grade=school.loc[school.grade=='10th', 'grade']
eleven_grade=school.loc[school.grade=='11th', 'grade']
twelve_grade=school.loc[school.grade=='12th', 'grade']
school['ninth_grade']=ninth_grade
school
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
# Out:
#                                Student ID  reading_score  math_score  \
# school_name           grade
# Bailey High School    10th   20365.058918      80.907183   76.996772
#                       11th   20345.148681      80.945643   77.515588
#                       12th   20386.724708      80.912451   76.492218
#                       9th    20344.481481      81.303155   77.083676
# Cabrera High School   10th   16909.487124      84.253219   83.154506
#                       11th   16955.047718      83.788382   82.765560
#                       12th   16924.570681      84.287958   83.277487
#                       9th    16969.634470      83.676136   83.094697
# Figueroa High School  10th    4332.703801      81.408912   76.539974
#                       11th    4424.478138      80.640339   76.884344
#                       12th    4414.922705      81.384863   77.151369
#                       9th     4397.878505      81.198598   76.403037
# ...

# %%
#Reading Scores by Grade

# %%
#Scores by School Spending

# %%
#Scores by School Size

# %%
#Scores by School Type
